# %% [markdown]
# # CAE2PC: Sampling CAE Models into 3D Point Clouds
#
# Intro
#
# ---

# %% [markdown]
# ## Sampling methods

# %% [markdown]
# ## Sampling a data set

# %% [markdown]
# ## Data normalization
